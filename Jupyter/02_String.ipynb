# %% [markdown]
# <a href="https://colab.research.google.com/github/rrajveersingh02/Python_Notebooks/blob/main/02_String.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # String - Any sequence of characters within either single quotes or double quotes is considered as a String

# %%
s1='Single quote String'
s2="Double quote STring"
s3="""Multi line
String"""
print(s1)
print(s2)
print(s3)
# Out:
# Single quote String
# Double quote STring
# Multi line
# String

# %%
type(s1)  # type
# Out:
# str

# %%
str1='Hello'
del str1     # delete string

# %%
print(id(s1))    # ID
print(id(s2))
print(id(s3))
# Out:
# 136641507563184
# 136641507570464
# 136641507559504

# %% [markdown]
# - String insertion values at any index of string we get type error bcoz String is immutable insertion not allowed

# %% [markdown]
# # String methods

# %%
s='sample string for performing operations'
print(len(s))                                   # length
# Out:
# 39

# %%
s="     This is new String for strip       "             # split
print(s.rstrip())  # remove spaces from right side
print(s.lstrip())  # remove spaces from left side
print(s.strip())  # remove spaces from both sides
# Out:
#      This is new String for strip
# This is new String for strip
# This is new String for strip

# %%
s='sample string for performing operations'
print(s.find('for'))                            # find -->> return starting index
# Out:
# 14

# %%
print(s.find('Raj',10,15))   # return -1 if substring not found
# Out:
# -1

# %%
print(s.find('for',10,100))  # return starting index of substring
# Out:
# 14

# %%
print(s.rfind('for',10,100))  # find from reverse
# Out:
# 21

# %%
print(s.index('for',10,100)) # if substring not found we get Value Error
# Out:
# 14

# %%
s1='Sample string values '      # count
s1.count('s')
s1.count('s',2,12)
# Out:
# 1

# %%
s1='Sample string for replace'
s1=s1.replace('for','ZZ')        # replace
print(s1)
# Out:
# Sample string ZZ replace

# %%
s1='Sample string for replace'
print(id(s1))
s1=s1.replace('for','ZZ')        # ID after replace
print(id(s1))
# Out:
# 136641509012096
# 136641507566384

# %%
splitList = s.split(' ')  # split , return type of split is list
print(splitList[0])
print(splitList[1])
print(splitList[2])
# Out:
# sample
# string
# for

# %%
jj='#'.join(splitList)         # join
jj
# Out:
# 'sample#string#for#performing#operations'

# %%
s1="This Is a New Sample String"
s1.lower()                              # lower case
# Out:
# 'this is a new sample string'

# %%
s1.upper()              # upper case
# Out:
# 'THIS IS A NEW SAMPLE STRING'

# %%
s='Sample'       # case fold -  convert upper case to lower
s.casefold()
# Out:
# 'sample'

# %%
s1.swapcase()  # swap case
# Out:
# 'tHIS iS A nEW sAMPLE sTRING'

# %%
s1.capitalize()  # capitalize
# Out:
# 'This is a new sample string'

# %%
s1.title()   # title
# Out:
# 'This Is A New Sample String'

# %%
s1.startswith('T')  # startswith
# Out:
# True

# %%
s1.startswith('z')
# Out:
# False

# %%
s1.endswith('Z')    # ends with
# Out:
# False

# %%
s='String Sample'           # reverse string using join
print(''.join(reversed(s)))
# Out:
# elpmaS gnirtS

# %%
s='String Sample'           # reverse string
print(s[::-1])
# Out:
# elpmaS gnirtS

# %%
s='Sample'                     # center
print(s.center(20,"Z"))
# Out:
# ZZZZZZZSampleZZZZZZZ

# %% [markdown]
# # Check type of character

# %%
s='StringSample123'
print(s.isalnum())
print(s.isalpha())
print(s.isdigit())
print(s.isspace())
# Out:
# True
# False
# False
# False

# %% [markdown]
# # Formating

# %%
name = 'Username'
salary = 10000
age = 50
print("{} 's salary is {} and his age is {}".format(name,salary,age))
print("{0} 's salary is {1} and his age is {2}".format(name,salary,age))
print("{x} 's salary is {y} and his age is {z}".format(z=age,y=salary,x=name))
# Out:
# Username 's salary is 10000 and his age is 50
# Username 's salary is 10000 and his age is 50
# Username 's salary is 10000 and his age is 50

# %%
s.__contains__('S')    # Contains
# Out:
# True

# %%
string = "\t\tCenter\t\t"
print(string.expandtabs())
# Out:
#                 Center

# %%
str = "I love Geeks for geeks"
print(str.partition("for"))
# Out:
# ('I love Geeks ', 'for', ' geeks')

# %%
def reverse(s):     # String reverse program
	str = ""
	for i in s:
		str = i + str
	return str

s = "Geeksforgeeks"

print("The original string is : ", end="")
print(s)

print("The reversed string(using loops) is : ", end="")
print(reverse(s))
# Out:
# The original string is : Geeksforgeeks
# The reversed string(using loops) is : skeegrofskeeG

# %% [markdown]
# # Slicing

# %%
s='Sample String'   # access string elements using index
print(s[0])
print(s[2])
print(s[5])
# Out:
# S
# m
# e

# %%
print(s[-2])   # access from reverse(Negative indexing)
print(s[-5])
# Out:
# n
# t

# %%
s="This is a sample string for slicing"
s[1:14]                                    # s[startIndex:endIndex]
# Out:
# 'his is a samp'

# %%
s="This is a sample string for slicing"
s[1:14:2]                                    # s[startIndex:endIndex:step]
# Out:
# 'hsi  ap'

# %%
print(s[0:100])  # if we pass max value than length it will print till end
# Out:
# This is a sample string for slicing

# %%
s[1:]
# Out:
# 'his is a sample string for slicing'

# %%
s[:100]
# Out:
# 'This is a sample string for slicing'

# %%
s[::]
# Out:
# 'This is a sample string for slicing'

# %%
print(s[-7:-1:1])
print(s[-1:-7:-1])
# Out:
# slicin
# gnicil

# %% [markdown]
# # Format

# %%
print("{} and {} both are the best friend".format("Devansh","Abhishek"))
# Out:
# Devansh and Abhishek both are the best friend

# %%
String1 = "{0:b}".format(16)
print("\nBinary representation of 16 is ")
print(String1)

# Formatting of Floats
String1 = "{0:e}".format(165.6458)
print("\nExponent representation of 165.6458 is ")
print(String1)

# Rounding off Integers
String1 = "{0:.2f}".format(1 / 6)
print("\none-sixth is : ")
print(String1)
# Out:
# Binary representation of 16 is
# 10000
#
# Exponent representation of 165.6458 is
# 1.656458e+02
#
# one-sixth is :
# 0.17
